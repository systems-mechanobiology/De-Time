# %% [markdown]
# # arXiv Agent and Coding-Agent Research Pulse
#
# This notebook tracks query-based research topics on arXiv. It is designed for fast-moving themes where category alone is too broad.
#
# Good first topics:
#
# - AI agents;
# - coding agents;
# - tool use;
# - retrieval-augmented generation;
# - mechanistic interpretability;
# - AI for science.
#
# Data source: arXiv API. No synthetic fallback.

# %%
from pathlib import Path
import os
import sys

import numpy as np
import pandas as pd

# Prefer the checkout when this notebook is run inside the repository.
repo_root = Path.cwd()
for candidate in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent, Path.cwd().parent.parent.parent]:
    if (candidate / "src" / "detime").exists():
        repo_root = candidate
        break
sys.path.insert(0, str(repo_root / "src"))
sys.path.insert(0, str(repo_root))

from examples.hot_trends.data import (
    HotTrendDataError,
    append_real_snapshot,
    build_arxiv_monthly_counts,
    fetch_coingecko_market_chart,
    fetch_defillama_stablecoin_chains,
    fetch_github_repo_metadata,
    fetch_github_stargazers,
    fetch_huggingface_models,
    fetch_wikipedia_pageviews,
    source_audit_table,
)
from examples.hot_trends.decomposition import (
    component_summary,
    decompose_table,
    editorial_priority,
    residual_event_table,
)
from examples.hot_trends.scoring import article_language_guardrails

pd.set_option("display.max_columns", 80)
pd.set_option("display.max_rows", 80)

CACHE_DIR = repo_root / "examples" / "hot_trends" / "cache"
OUTPUT_DIR = repo_root / "examples" / "hot_trends" / "outputs"
CACHE_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

def save_table(df, name):
    path = OUTPUT_DIR / f"{name}.csv"
    df.to_csv(path, index=False)
    relative_path = path.relative_to(repo_root).as_posix()
    print(f"saved: {relative_path}")

# %% [markdown]
# ## 1. Define query pulses
#
# The queries below are deliberately explicit. Adjust them when the arXiv API parser or field syntax requires a stricter expression.

# %%
topic_queries = {
    "ai_agent": 'all:"AI agent" OR all:"autonomous agent"',
    "coding_agent": 'all:"coding agent" OR all:"code agent" OR all:"program repair"',
    "tool_use": 'all:"tool use" OR all:"function calling"',
    "rag": 'all:"retrieval augmented generation" OR all:"RAG"',
    "mechanistic_interpretability": 'all:"mechanistic interpretability"',
    "ai_for_science": 'all:"AI for science" OR all:"scientific discovery"',
}
pd.DataFrame([{"topic": k, "query": v} for k, v in topic_queries.items()])
# Out:
#                           topic  \
# 0                      ai_agent
# 1                  coding_agent
# 2                      tool_use
# 3                           rag
# 4  mechanistic_interpretability
# 5                ai_for_science
#
#                                                query
# 0           all:"AI agent" OR all:"autonomous agent"
# 1  all:"coding agent" OR all:"code agent" OR all:...
# 2           all:"tool use" OR all:"function calling"
# 3  all:"retrieval augmented generation" OR all:"RAG"
# 4                 all:"mechanistic interpretability"
# 5  all:"AI for science" OR all:"scientific discov...

# %% [markdown]
# ## 2. Fetch real monthly topic counts

# %%
START_MONTH = "2025-01-01"
END_MONTH = "2026-05-01"
SLEEP_SECONDS = 3.0

cache_path = CACHE_DIR / f"arxiv_agent_topic_counts_{START_MONTH}_{END_MONTH}.csv"
if cache_path.exists():
    counts = pd.read_csv(cache_path, parse_dates=["month"])
else:
    counts = build_arxiv_monthly_counts(topic_queries, start_month=START_MONTH, end_month=END_MONTH, sleep_seconds=SLEEP_SECONDS)
    counts.to_csv(cache_path, index=False)
counts.head(12)
# Out:
#         month    series                                     query  count  \
# 0  2025-01-01  ai_agent  all:"AI agent" OR all:"autonomous agent"     65
# 1  2025-02-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    112
# 2  2025-03-01  ai_agent  all:"AI agent" OR all:"autonomous agent"     91
# 3  2025-04-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    115
# 4  2025-05-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    173
# 5  2025-06-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    150
# 6  2025-07-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    131
# 7  2025-08-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    163
# 8  2025-09-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    158
# 9  2025-10-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    206
# 10 2025-11-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    162
# 11 2025-12-01  ai_agent  all:"AI agent" OR all:"autonomous agent"    172
#
#        source access_date                           data_quality
# 0   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 1   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 2   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 3   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 4   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 5   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 6   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 7   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 8   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 9   arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 10  arXiv API  2026-05-22  live_public_api_no_synthetic_fallback
# 11  arXiv API  2026-05-22  live_public_api_no_synthetic_fallback

# %% [markdown]
# ## 3. Source audit

# %%
audit = source_audit_table(counts, value_col="count", entity_col="series", time_col="month")
audit
# Out:
#                          series      first_timestamp       last_timestamp  \
# 0                      ai_agent  2025-01-01 00:00:00  2026-05-01 00:00:00
# 1                ai_for_science  2025-01-01 00:00:00  2026-05-01 00:00:00
# 2                  coding_agent  2025-01-01 00:00:00  2026-05-01 00:00:00
# 3  mechanistic_interpretability  2025-01-01 00:00:00  2026-05-01 00:00:00
# 4                           rag  2025-01-01 00:00:00  2026-05-01 00:00:00
# 5                      tool_use  2025-01-01 00:00:00  2026-05-01 00:00:00
#
#    observations  missing_ratio  min_value  max_value
# 0            17            0.0       65.0      365.0
# 1            17            0.0       21.0       63.0
# 2            17            0.0        8.0      118.0
# 3            17            0.0        9.0       62.0
# 4            17            0.0      154.0      336.0
# 5            17            0.0       44.0      182.0

# %% [markdown]
# ## 4. Decompose topic counts

# %%
components = decompose_table(
    counts,
    entity_col="series",
    time_col="month",
    value_col="count",
    method="MA_BASELINE",
    period=12,
    trend_window=5,
    transform="log1p",
)
summary = component_summary(components, entity_col="series", time_col="month")
summary
# Out:
#                          series  observations      first_timestamp  \
# 0                      ai_agent            17  2025-01-01 00:00:00
# 1                ai_for_science            17  2025-01-01 00:00:00
# 2                  coding_agent            17  2025-01-01 00:00:00
# 3  mechanistic_interpretability            17  2025-01-01 00:00:00
# 4                           rag            17  2025-01-01 00:00:00
# 5                      tool_use            17  2025-01-01 00:00:00
#
#         last_timestamp  trend_last  trend_slope_per_step  \
# 0  2026-05-01 00:00:00    3.418475              0.059586
# 1  2026-05-01 00:00:00    2.489031              0.034805
# 2  2026-05-01 00:00:00    2.792028              0.109713
# 3  2026-05-01 00:00:00    2.343744              0.047719
# 4  2026-05-01 00:00:00    3.389279              0.013511
# 5  2026-05-01 00:00:00    3.035190              0.064324
#
#    cycle_strength_proxy  residual_std  max_abs_residual_z       method
# 0             -0.477001      0.503611            2.513110  MA_BASELINE
# 1             -1.013129      0.387375           14.858083  MA_BASELINE
# 2              0.697921      0.414089            6.951002  MA_BASELINE
# 3              0.444266      0.318825            3.834405  MA_BASELINE
# 4             -6.572506      0.536696            6.078962  MA_BASELINE
# 5             -0.197874      0.467042           12.071310  MA_BASELINE

# %% [markdown]
# ## 5. Editorial ranking
#
# A topic with both positive trend slope and high residual shock deserves a timely post. A topic with trend but low residual is better for an evergreen explainer.

# %%
priority = editorial_priority(summary, entity_col="series")
priority
# Out:
#                          series  observations      first_timestamp  \
# 2                  coding_agent            17  2025-01-01 00:00:00
# 5                      tool_use            17  2025-01-01 00:00:00
# 1                ai_for_science            17  2025-01-01 00:00:00
# 3  mechanistic_interpretability            17  2025-01-01 00:00:00
# 0                      ai_agent            17  2025-01-01 00:00:00
# 4                           rag            17  2025-01-01 00:00:00
#
#         last_timestamp  trend_last  trend_slope_per_step  \
# 2  2026-05-01 00:00:00    2.792028              0.109713
# 5  2026-05-01 00:00:00    3.035190              0.064324
# 1  2026-05-01 00:00:00    2.489031              0.034805
# 3  2026-05-01 00:00:00    2.343744              0.047719
# 0  2026-05-01 00:00:00    3.418475              0.059586
# 4  2026-05-01 00:00:00    3.389279              0.013511
#
#    cycle_strength_proxy  residual_std  max_abs_residual_z       method  \
# 2              0.697921      0.414089            6.951002  MA_BASELINE
# 5             -0.197874      0.467042           12.071310  MA_BASELINE
# 1             -1.013129      0.387375           14.858083  MA_BASELINE
# 3              0.444266      0.318825            3.834405  MA_BASELINE
# 0             -0.477001      0.503611            2.513110  MA_BASELINE
# 4             -6.572506      0.536696            6.078962  MA_BASELINE
#
#    trend_slope_per_step_rank_pct  cycle_strength_proxy_rank_pct  \
# 2                       1.000000                       1.000000
# 5                       0.833333                       0.666667
# 1                       0.333333                       0.333333
# 3                       0.500000                       0.833333
# 0                       0.666667                       0.500000
# 4                       0.166667                       0.166667
#
#    max_abs_residual_z_rank_pct  editorial_priority_score
# 2                     0.666667                  0.850000
# 5                     0.833333                  0.800000
# 1                     1.000000                  0.633333
# 3                     0.333333                  0.491667
# 0                     0.166667                  0.408333
# 4                     0.500000                  0.316667

# %% [markdown]
# ## 6. Event-like months

# %%
events = residual_event_table(components, entity_col="series", time_col="month", top_n=20)
events
# Out:
#         month          series  observed     trend    season  residual  \
# 0  2026-05-01  ai_for_science  4.143135  2.489031  0.614325  1.039779
# 1  2025-05-01  ai_for_science  3.850148  3.751483  0.614325 -0.515660
# 2  2026-05-01        tool_use  5.209486  3.035190  0.841468  1.332828
# 3  2025-05-01        tool_use  4.304065  4.162151  0.841468 -0.699554
# 4  2025-04-01  ai_for_science  3.496508  3.727357  0.033679 -0.264529
# 5  2026-04-01  ai_for_science  4.143135  3.320807  0.033679  0.788648
# 6  2026-01-01  ai_for_science  4.094345  4.042209  0.270311 -0.218175
# 7  2025-01-01  ai_for_science  3.091042  2.078438  0.270311  0.742294
# 8  2025-01-01        tool_use  3.806662  2.351080  0.482440  0.973142
# 9  2026-01-01        tool_use  4.905275  4.762703  0.482440 -0.339868
# 10 2026-02-01  ai_for_science  4.158883  4.076777  0.221904 -0.139799
# 11 2025-02-01  ai_for_science  3.663562  2.777740  0.221904  0.663918
# 12 2026-05-01    coding_agent  4.762174  2.792028  0.821414  1.148732
# 13 2025-05-01    coding_agent  3.218876  3.049585  0.821414 -0.652123
# 14 2025-04-01        tool_use  4.025352  4.110964  0.131995 -0.217608
# 15 2026-04-01        tool_use  5.010635  4.027759  0.131995  0.850881
# 16 2026-05-01             rag  5.468060  3.389279  0.824523  1.254258
# 17 2025-05-01             rag  5.820083  5.490040  0.824523 -0.494480
# 18 2026-01-01             rag  5.736572  5.550336  0.652466 -0.466230
# 19 2025-01-01             rag  5.043425  3.164951  0.652466  1.226008
#
#     residual_z  abs_residual_z       method
# 0    14.858083       14.858083  MA_BASELINE
# 1   -14.858083       14.858083  MA_BASELINE
# 2    12.071310       12.071310  MA_BASELINE
# 3   -12.071310       12.071310  MA_BASELINE
# 4   -10.060305       10.060305  MA_BASELINE
# 5    10.060305       10.060305  MA_BASELINE
# 6    -9.174720        9.174720  MA_BASELINE
# 7     9.174720        9.174720  MA_BASELINE
# 8     7.798611        7.798611  MA_BASELINE
# 9    -7.798611        7.798611  MA_BASELINE
# 10   -7.677369        7.677369  MA_BASELINE
# 11    7.677369        7.677369  MA_BASELINE
# 12    6.951002        6.951002  MA_BASELINE
# 13   -6.951002        6.951002  MA_BASELINE
# 14   -6.346279        6.346279  MA_BASELINE
# 15    6.346279        6.346279  MA_BASELINE
# 16    6.078962        6.078962  MA_BASELINE
# 17   -6.078962        6.078962  MA_BASELINE
# 18   -5.882558        5.882558  MA_BASELINE
# 19    5.882558        5.882558  MA_BASELINE

# %% [markdown]
# ## 7. Article outline template

# %%
outline = pd.DataFrame([
    {"section": "Question", "content": "Which agent-related research topic is accelerating?"},
    {"section": "Source", "content": "arXiv API counts by query and submitted month."},
    {"section": "De-Time table", "content": "trend slope, cycle strength, residual shock rank."},
    {"section": "Caveat", "content": "arXiv counts measure preprint volume, not research quality or adoption."},
])
outline
# Out:
#          section                                            content
# 0       Question  Which agent-related research topic is accelera...
# 1         Source     arXiv API counts by query and submitted month.
# 2  De-Time table  trend slope, cycle strength, residual shock rank.
# 3         Caveat  arXiv counts measure preprint volume, not rese...

# %%
save_table(audit, "02_arxiv_agent_topic_audit")
save_table(priority, "02_arxiv_agent_topic_priority")
save_table(events, "02_arxiv_agent_topic_residual_events")
save_table(outline, "02_arxiv_agent_article_outline")
# Out:
# saved: examples/hot_trends/outputs/02_arxiv_agent_topic_audit.csv
# saved: examples/hot_trends/outputs/02_arxiv_agent_topic_priority.csv
# saved: examples/hot_trends/outputs/02_arxiv_agent_topic_residual_events.csv
# saved: examples/hot_trends/outputs/02_arxiv_agent_article_outline.csv
