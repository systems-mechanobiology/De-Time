# %% [markdown]
# # arXiv Category Pulse
#
# This notebook counts real arXiv submissions by category and decomposes the resulting monthly count series.
#
# Use it for articles such as:
#
# - Which AI fields are actually accelerating?
# - Is `cs.CL` still rising after the LLM boom?
# - Are biology and finance categories showing durable AI-adjacent growth?
#
# Data source: arXiv API. No synthetic fallback.

# %%
from pathlib import Path
import os
import sys

import numpy as np
import pandas as pd

# Prefer the checkout when this notebook is run inside the repository.
repo_root = Path.cwd()
for candidate in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent, Path.cwd().parent.parent.parent]:
    if (candidate / "src" / "detime").exists():
        repo_root = candidate
        break
sys.path.insert(0, str(repo_root / "src"))
sys.path.insert(0, str(repo_root))

from examples.hot_trends.data import (
    HotTrendDataError,
    append_real_snapshot,
    build_arxiv_monthly_counts,
    fetch_coingecko_market_chart,
    fetch_defillama_stablecoin_chains,
    fetch_github_repo_metadata,
    fetch_github_stargazers,
    fetch_huggingface_models,
    fetch_wikipedia_pageviews,
    source_audit_table,
)
from examples.hot_trends.decomposition import (
    component_summary,
    decompose_table,
    editorial_priority,
    residual_event_table,
)
from examples.hot_trends.scoring import article_language_guardrails

pd.set_option("display.max_columns", 80)
pd.set_option("display.max_rows", 80)

CACHE_DIR = repo_root / "examples" / "hot_trends" / "cache"
OUTPUT_DIR = repo_root / "examples" / "hot_trends" / "outputs"
CACHE_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

def save_table(df, name):
    path = OUTPUT_DIR / f"{name}.csv"
    df.to_csv(path, index=False)
    relative_path = path.relative_to(repo_root).as_posix()
    print(f"saved: {relative_path}")

# %% [markdown]
# ## 1. Define the category watchlist

# %%
queries = {
    "cs.AI": "cat:cs.AI",
    "cs.LG": "cat:cs.LG",
    "cs.CL": "cat:cs.CL",
    "cs.CV": "cat:cs.CV",
    "stat.ML": "cat:stat.ML",
    "q-bio.QM": "cat:q-bio.QM",
    "q-fin.ST": "cat:q-fin.ST",
    "econ.EM": "cat:econ.EM",
}
watchlist = pd.DataFrame([{"series": k, "query": v} for k, v in queries.items()])
watchlist
# Out:
#      series         query
# 0     cs.AI     cat:cs.AI
# 1     cs.LG     cat:cs.LG
# 2     cs.CL     cat:cs.CL
# 3     cs.CV     cat:cs.CV
# 4   stat.ML   cat:stat.ML
# 5  q-bio.QM  cat:q-bio.QM
# 6  q-fin.ST  cat:q-fin.ST
# 7   econ.EM   cat:econ.EM

# %% [markdown]
# ## 2. Fetch real monthly counts
#
# The default window is intentionally modest so the notebook can run without hammering the API. Increase the window for a full article.

# %%
START_MONTH = "2025-01-01"
END_MONTH = "2026-05-01"
SLEEP_SECONDS = 3.0

cache_path = CACHE_DIR / f"arxiv_category_counts_{START_MONTH}_{END_MONTH}.csv"
if cache_path.exists():
    counts = pd.read_csv(cache_path, parse_dates=["month"])
else:
    counts = build_arxiv_monthly_counts(queries, start_month=START_MONTH, end_month=END_MONTH, sleep_seconds=SLEEP_SECONDS)
    counts.to_csv(cache_path, index=False)
counts.head(16)
# Out:
#         month series      query  count     source access_date  \
# 0  2025-01-01  cs.AI  cat:cs.AI   2485  arXiv API  2026-05-22
# 1  2025-02-01  cs.AI  cat:cs.AI   3761  arXiv API  2026-05-22
# 2  2025-03-01  cs.AI  cat:cs.AI   3406  arXiv API  2026-05-22
# 3  2025-04-01  cs.AI  cat:cs.AI   3031  arXiv API  2026-05-22
# 4  2025-05-01  cs.AI  cat:cs.AI   4805  arXiv API  2026-05-22
# 5  2025-06-01  cs.AI  cat:cs.AI   3949  arXiv API  2026-05-22
# 6  2025-07-01  cs.AI  cat:cs.AI   3474  arXiv API  2026-05-22
# 7  2025-08-01  cs.AI  cat:cs.AI   3825  arXiv API  2026-05-22
# 8  2025-09-01  cs.AI  cat:cs.AI   4260  arXiv API  2026-05-22
# 9  2025-10-01  cs.AI  cat:cs.AI   4844  arXiv API  2026-05-22
# 10 2025-11-01  cs.AI  cat:cs.AI   3919  arXiv API  2026-05-22
# 11 2025-12-01  cs.AI  cat:cs.AI   3374  arXiv API  2026-05-22
# 12 2026-01-01  cs.AI  cat:cs.AI   4201  arXiv API  2026-05-22
# 13 2026-02-01  cs.AI  cat:cs.AI   4448  arXiv API  2026-05-22
# 14 2026-03-01  cs.AI  cat:cs.AI   5018  arXiv API  2026-05-22
# 15 2026-04-01  cs.AI  cat:cs.AI   4784  arXiv API  2026-05-22
#
#                              data_quality
# 0   live_public_api_no_synthetic_fallback
# 1   live_public_api_no_synthetic_fallback
# 2   live_public_api_no_synthetic_fallback
# 3   live_public_api_no_synthetic_fallback
# 4   live_public_api_no_synthetic_fallback
# 5   live_public_api_no_synthetic_fallback
# 6   live_public_api_no_synthetic_fallback
# 7   live_public_api_no_synthetic_fallback
# 8   live_public_api_no_synthetic_fallback
# 9   live_public_api_no_synthetic_fallback
# 10  live_public_api_no_synthetic_fallback
# 11  live_public_api_no_synthetic_fallback
# 12  live_public_api_no_synthetic_fallback
# 13  live_public_api_no_synthetic_fallback
# 14  live_public_api_no_synthetic_fallback
# 15  live_public_api_no_synthetic_fallback

# %% [markdown]
# ## 3. Audit the real source table

# %%
audit = source_audit_table(counts, value_col="count", entity_col="series", time_col="month")
audit
# Out:
#      series      first_timestamp       last_timestamp  observations  \
# 0     cs.AI  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 1     cs.CL  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 2     cs.CV  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 3     cs.LG  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 4   econ.EM  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 5  q-bio.QM  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 6  q-fin.ST  2025-01-01 00:00:00  2026-05-01 00:00:00            17
# 7   stat.ML  2025-01-01 00:00:00  2026-05-01 00:00:00            17
#
#    missing_ratio  min_value  max_value
# 0            0.0     2485.0     5018.0
# 1            0.0     1312.0     2954.0
# 2            0.0     2052.0     4059.0
# 3            0.0     3000.0     5054.0
# 4            0.0       48.0      112.0
# 5            0.0       91.0      153.0
# 6            0.0       16.0       38.0
# 7            0.0      344.0      767.0

# %% [markdown]
# ## 4. Decompose counts with De-Time
#
# For monthly counts, period 12 is the first cycle to test. The method is `MA_BASELINE` by default because it is built into De-Time and keeps the tutorial dependency-light.

# %%
components = decompose_table(
    counts,
    entity_col="series",
    time_col="month",
    value_col="count",
    method="MA_BASELINE",
    period=12,
    trend_window=5,
    transform="log1p",
)
components.head(16)
# Out:
#         month series  observed     trend    season  residual       method  \
# 0  2025-01-01  cs.AI  7.818430  4.836945  0.918014  2.063471  MA_BASELINE
# 1  2025-02-01  cs.AI  8.232706  6.440340  0.332074  1.460292  MA_BASELINE
# 2  2025-03-01  cs.AI  8.133587  8.135864 -0.532397  0.530121  MA_BASELINE
# 3  2025-04-01  cs.AI  8.016978  8.228472  0.173453 -0.384948  MA_BASELINE
# 4  2025-05-01  cs.AI  8.477620  8.212601  1.214337 -0.949318  MA_BASELINE
# 5  2025-06-01  cs.AI  8.281471  8.235799 -0.532441  0.578113  MA_BASELINE
# 6  2025-07-01  cs.AI  8.153350  8.303855 -0.728619  0.578113  MA_BASELINE
# 7  2025-08-01  cs.AI  8.249575  8.305471 -0.634010  0.578113  MA_BASELINE
# 8  2025-09-01  cs.AI  8.357259  8.303947 -0.524801  0.578113  MA_BASELINE
# 9  2025-10-01  cs.AI  8.485703  8.298107 -0.390518  0.578113  MA_BASELINE
# 10 2025-11-01  cs.AI  8.273847  8.316855 -0.621121  0.578113  MA_BASELINE
# 11 2025-12-01  cs.AI  8.124151  8.325490 -0.779453  0.578113  MA_BASELINE
# 12 2026-01-01  cs.AI  8.343316  8.332547  0.918014 -0.907245  MA_BASELINE
# 13 2026-02-01  cs.AI  8.400435  8.372426  0.332074 -0.304065  MA_BASELINE
# 14 2026-03-01  cs.AI  8.520986  8.427277 -0.532397  0.626106  MA_BASELINE
# 15 2026-04-01  cs.AI  8.473241  6.758614  0.173453  1.541174  MA_BASELINE
#
#     period transform
# 0       12     log1p
# 1       12     log1p
# 2       12     log1p
# 3       12     log1p
# 4       12     log1p
# 5       12     log1p
# 6       12     log1p
# 7       12     log1p
# 8       12     log1p
# 9       12     log1p
# 10      12     log1p
# 11      12     log1p
# 12      12     log1p
# 13      12     log1p
# 14      12     log1p
# 15      12     log1p

# %% [markdown]
# ## 5. Rank fields by trend and residual shock

# %%
summary = component_summary(components, entity_col="series", time_col="month")
priority = editorial_priority(summary, entity_col="series")
priority
# Out:
#      series  observations      first_timestamp       last_timestamp  \
# 3     cs.LG            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 4   econ.EM            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 0     cs.AI            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 5  q-bio.QM            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 2     cs.CV            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 6  q-fin.ST            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 1     cs.CL            17  2025-01-01 00:00:00  2026-05-01 00:00:00
# 7   stat.ML            17  2025-01-01 00:00:00  2026-05-01 00:00:00
#
#    trend_last  trend_slope_per_step  cycle_strength_proxy  residual_std  \
# 3    5.017982              0.007983            -29.718421      0.872881
# 4    2.694439              0.025516             -3.497653      0.479359
# 0    5.078527              0.018128            -21.214366      0.857312
# 5    2.826560             -0.003319            -11.445934      0.508898
# 2    4.863904              0.006207            -23.594874      0.844894
# 6    1.991595              0.012333             -1.209950      0.305315
# 1    4.579115              0.000606            -10.569187      0.760387
# 7    3.815449              0.003491             -7.626177      0.673733
#
#    max_abs_residual_z       method  trend_slope_per_step_rank_pct  \
# 3           62.286532  MA_BASELINE                          0.625
# 4            6.797311  MA_BASELINE                          1.000
# 0           21.466554  MA_BASELINE                          0.875
# 5          135.798595  MA_BASELINE                          0.125
# 2           39.630611  MA_BASELINE                          0.500
# 6            2.004959  MA_BASELINE                          0.750
# 1           31.452320  MA_BASELINE                          0.250
# 7            8.585748  MA_BASELINE                          0.375
#
#    cycle_strength_proxy_rank_pct  max_abs_residual_z_rank_pct  \
# 3                          0.125                        0.875
# 4                          0.875                        0.250
# 0                          0.375                        0.500
# 5                          0.500                        1.000
# 2                          0.250                        0.750
# 6                          1.000                        0.125
# 1                          0.625                        0.625
# 7                          0.750                        0.375
#
#    editorial_priority_score
# 3                   0.63750
# 4                   0.63750
# 0                   0.60625
# 5                   0.59375
# 2                   0.56250
# 6                   0.51875
# 1                   0.49375
# 7                   0.45000

# %% [markdown]
# ## 6. Top residual events
#
# These rows are article hooks. They do not prove causality; they mark months that do not fit the smooth trend/cycle baseline.

# %%
events = residual_event_table(components, entity_col="series", time_col="month", top_n=20)
events
# Out:
#         month    series  observed     trend    season  residual  residual_z  \
# 0  2025-01-01  q-bio.QM  4.624973  2.822589  0.512617  1.289767  135.798595
# 1  2026-01-01  q-bio.QM  4.615121  4.735994  0.512617 -0.633490 -135.798595
# 2  2025-05-01  q-bio.QM  4.990433  4.813606  0.692669 -0.515842 -119.184690
# 3  2026-05-01  q-bio.QM  4.691348  2.826560  0.692669  1.172119  119.184690
# 4  2025-04-01  q-bio.QM  4.595120  4.772203  0.044841 -0.221925  -77.678425
# 5  2026-04-01  q-bio.QM  4.653960  3.730918  0.044841  0.878202   77.678425
# 6  2026-02-01  q-bio.QM  4.521789  4.681335  0.023867 -0.183413  -72.239976
# 7  2025-02-01  q-bio.QM  4.605170  3.741613  0.023867  0.839690   72.239976
# 8  2026-01-01     cs.LG  8.225503  8.277744  0.934998 -0.987239  -62.286532
# 9  2025-01-01     cs.LG  8.006701  4.918570  0.934998  2.153133   62.286532
# 10 2025-05-01     cs.LG  8.528133  8.236510  1.276077 -0.984454  -62.176076
# 11 2026-05-01     cs.LG  8.444407  5.017982  1.276077  2.150348   62.176076
# 12 2025-01-01     cs.CV  7.627057  4.721890  0.795382  2.109786   39.630611
# 13 2026-01-01     cs.CV  7.801800  8.012935  0.795382 -1.006516  -39.630611
# 14 2026-05-01     cs.CV  7.913155  4.863904  1.002250  2.047002   38.033743
# 15 2025-05-01     cs.CV  8.098947  8.040429  1.002250 -0.943732  -38.033743
# 16 2025-04-01     cs.LG  8.012018  8.284370  0.063321 -0.335673  -36.440039
# 17 2026-04-01     cs.LG  8.273337  6.708449  0.063321  1.501566   36.440039
# 18 2025-02-01     cs.LG  8.374938  6.520974  0.428431  1.425534   33.423958
# 19 2026-02-01     cs.LG  8.452335  8.283544  0.428431 -0.259640  -33.423958
#
#     abs_residual_z       method
# 0       135.798595  MA_BASELINE
# 1       135.798595  MA_BASELINE
# 2       119.184690  MA_BASELINE
# 3       119.184690  MA_BASELINE
# 4        77.678425  MA_BASELINE
# 5        77.678425  MA_BASELINE
# 6        72.239976  MA_BASELINE
# 7        72.239976  MA_BASELINE
# 8        62.286532  MA_BASELINE
# 9        62.286532  MA_BASELINE
# 10       62.176076  MA_BASELINE
# 11       62.176076  MA_BASELINE
# 12       39.630611  MA_BASELINE
# 13       39.630611  MA_BASELINE
# 14       38.033743  MA_BASELINE
# 15       38.033743  MA_BASELINE
# 16       36.440039  MA_BASELINE
# 17       36.440039  MA_BASELINE
# 18       33.423958  MA_BASELINE
# 19       33.423958  MA_BASELINE

# %% [markdown]
# ## 7. Article-ready language

# %%
guardrails = article_language_guardrails()
guardrails
# Out:
#                                               unsafe  \
# 0           This trend predicts the next price move.
# 1  This model is better because it has more downl...
# 2     This repo is winning because stars are rising.
# 3             This pageview spike proves importance.
# 4                     This residual is a buy signal.
#
#                                                safer
# 0  This trend summarizes the observed public seri...
# 1  Downloads are a public adoption proxy and shou...
# 2  Star velocity measures developer attention, no...
# 3  Pageviews measure public attention during the ...
# 4  This residual marks an event-like deviation fr...

# %%
save_table(watchlist, "01_arxiv_category_watchlist")
save_table(audit, "01_arxiv_category_audit")
save_table(priority, "01_arxiv_category_priority")
save_table(events, "01_arxiv_category_residual_events")
save_table(guardrails, "01_arxiv_category_guardrails")
# Out:
# saved: examples/hot_trends/outputs/01_arxiv_category_watchlist.csv
# saved: examples/hot_trends/outputs/01_arxiv_category_audit.csv
# saved: examples/hot_trends/outputs/01_arxiv_category_priority.csv
# saved: examples/hot_trends/outputs/01_arxiv_category_residual_events.csv
# saved: examples/hot_trends/outputs/01_arxiv_category_guardrails.csv
